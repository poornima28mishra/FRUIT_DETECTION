# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
cnn = tf.keras.models.load_model("C:/Users/Poorn/Documents/my_model.keras")

# %%
import cv2
image_path = "D:/PROJECT/Fruit_dataset/test/apple/Image_1.jpg"
img = cv2.imread(image_path)
plt.imshow(img)
plt.title("test img")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64,3))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr =np.array([input_arr])
prediction = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step

# %%
print(prediction[0])
print(max(prediction[0]))
# Out:
# [9.94385242e-01 4.26878955e-07 6.66761189e-05 3.57772848e-07
#  4.42104842e-09 4.37715370e-03 1.50998994e-05 3.62479312e-07
#  3.82370587e-07 1.18412906e-07 8.34034353e-09 7.37416839e-09
#  3.00146894e-08 1.69182197e-08 7.38658770e-08 6.52665264e-08
#  3.94302191e-09 7.88294187e-07 3.13298304e-10 5.35599547e-08
#  2.59154214e-04 1.31056386e-05 3.41956038e-04 7.52041451e-05
#  2.10747322e-10 8.36111695e-08 1.72151544e-04 1.09653183e-06
#  3.64144144e-05 6.59684840e-09 8.25533999e-12 8.70227801e-09
#  1.02283057e-05 1.44620091e-04 5.44634167e-06 9.36904180e-05]
# 0.99438524

# %%
test_set= tf.keras.utils.image_dataset_from_directory("D:/PROJECT/Fruit_dataset/test",
            labels = 'inferred',
            label_mode='categorical',
            class_names=None,
            color_mode='rgb',
            batch_size=32,
            image_size= (64,64),
            shuffle=True,
            seed=None,
            validation_split=None,
            subset =None,
            interpolation='bilinear',
            follow_links=False,
            crop_to_aspect_ratio=False
        )
# Out:
# Found 359 files belonging to 36 classes.

# %%
test_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
result_index = np.where(prediction[0] == max(prediction[0]))
print(result_index[0][0])
# Out:
# 0

# %%
#display image
plt.imshow(img)
plt.title("test img")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print('it is a {}'.format(test_set.class_names[result_index[0][0]]))
# Out:
# it is a apple
